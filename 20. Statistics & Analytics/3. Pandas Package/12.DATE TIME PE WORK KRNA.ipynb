# %%
import pandas as pd

# %%
df=pd.read_csv("e:/dataset/analysis/movies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.actors_list=='Robbins']
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, category, duration, actors_list]
# Index: []

# %% [markdown]
# #### **isin() method**
# - isin method kisi data ke column me, column name exist krta hai ya nahi jaise- actors_list, category

# %%
df[df.actors_list.isin]
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# - **str** kisi value ko string me convert krna
# #### **contains() method**
# - contains method kisi value ko phle string me convert kr ke uspe fer contain method lagayege to, jis name ki value hum search krte hai, wo la ke hume dege.

# %%
df[df.actors_list.str.contains("Robbins")]
# Out:
#      star_rating                     title content_rating category  duration  \
# 0            9.3  The Shawshank Redemption              R    Crime       142
# 365          8.0              Mystic River              R    Crime       138
# 611          7.7                Short Cuts              R   Comedy       187
# 693          7.7                The Player              R   Comedy       124
# 819          7.6            Jacob's Ladder              R    Drama       113
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 365     [u'Sean Penn', u'Tim Robbins', u'Kevin Bacon']
# 611  [u'Andie MacDowell', u'Julianne Moore', u'Tim ...
# 693   [u'Tim Robbins', u'Greta Scacchi', u'Fred Ward']
# 819  [u'Tim Robbins', u'Elizabeth Pe\xf1a', u'Danny...

# %%
df[df.actors_list.str.contains("amir")]
# Out:
#      star_rating                              title content_rating   category  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 239          8.1      Elite Squad: The Enemy Within        UNRATED     Action
# 261          8.1                        Elite Squad              R     Action
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# ...

# %%
df[df.actors_list.str.contains("Amir Khan",case=False)]
# Out:
#      star_rating                              title content_rating   category  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
df[df.actors_list.str.contains("priyanka",case=False)]
# Out:
#      star_rating   title content_rating   category  duration  \
# 133          8.3  Barfi!      NOT RATED  Adventure       151
#
#                                            actors_list
# 133  [u'Ranbir Kapoor', u'Priyanka Chopra', u'Ileana']

# %%
df[df.category.isin(["Drama","Comedy"])]
# Out:
#      star_rating                            title content_rating category  \
# 5            8.9                     12 Angry Men      NOT RATED    Drama
# 9            8.9                       Fight Club              R    Drama
# 13           8.8                     Forrest Gump          PG-13    Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R    Drama
# 17           8.7                    Seven Samurai        UNRATED    Drama
# ..           ...                              ...            ...      ...
# 970          7.4                      Wonder Boys              R    Drama
# 971          7.4               Death at a Funeral              R   Comedy
# 972          7.4                   Blue Valentine          NC-17    Drama
# 973          7.4            The Cider House Rules          PG-13    Drama
# 974          7.4                          Tootsie             PG   Comedy
#
#      duration                                        actors_list
# ...

# %%
df[(df.category=="Drama") | (df.category=="Comedy")]
# Out:
#      star_rating                            title content_rating category  \
# 5            8.9                     12 Angry Men      NOT RATED    Drama
# 9            8.9                       Fight Club              R    Drama
# 13           8.8                     Forrest Gump          PG-13    Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R    Drama
# 17           8.7                    Seven Samurai        UNRATED    Drama
# ..           ...                              ...            ...      ...
# 970          7.4                      Wonder Boys              R    Drama
# 971          7.4               Death at a Funeral              R   Comedy
# 972          7.4                   Blue Valentine          NC-17    Drama
# 973          7.4            The Cider House Rules          PG-13    Drama
# 974          7.4                          Tootsie             PG   Comedy
#
#      duration                                        actors_list
# ...

# %%
#ye toda alag hai jo abhi tak pada hai.
df=pd.read_csv("E:/dataset/analysis/ufo.csv")         #UFO=unidentify flying object (aakash me udne wale object)
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# #### **DATE TIME PE WORK KRNA**

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %% [markdown]
# - **important**
# #### kisi ek **data type** se us data type ko kisi dusre **data type** me convert krna ho to.
# - **to_datetime**

# %%
df['date_time']=pd.to_datetime(df.Time)

# %%
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time                       object
# date_time          datetime64[ns]
# dtype: object

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time           date_time
# 0        6/1/1930 22:00 1930-06-01 22:00:00
# 1       6/30/1930 20:00 1930-06-30 20:00:00
# 2       2/15/1931 14:00 1931-02-15 14:00:00
# ...

# %% [markdown]
# ### **dt properties**
# - ye datetime se related hota hai.
# - ye date_time column me date, time, year, day, ki series deta hai.

# %%
df["year"]=df.date_time.dt.year
df["month"]=df.date_time.dt.month_name()
df["day"]=df.date_time.dt.day_name()

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time           date_time  year     month      day
# 0        6/1/1930 22:00 1930-06-01 22:00:00  1930      June   Sunday
# ...

# %%
df.year.value_counts()
# Out:
# 1999    2774
# 2000    2635
# 1998    1743
# 1995    1344
# 1997    1237
#         ...
# 1936       2
# 1930       2
# 1935       1
# 1934       1
# 1933       1
# Name: year, Length: 68, dtype: int64

# %%
df.day.value_counts()
# Out:
# Tuesday      2822
# Sunday       2689
# Saturday     2687
# Friday       2669
# Thursday     2598
# Wednesday    2476
# Monday       2300
# Name: day, dtype: int64

# %%
df.month.value_counts()
# Out:
# June         3059
# July         2345
# August       1948
# October      1723
# September    1635
# November     1509
# May          1168
# March        1096
# April        1045
# December     1034
# January       862
# February      817
# Name: month, dtype: int64

# %%
df[(df.year==1999) & (df.month=="June") & (df.day=="Tuesday")].shape
# Out:
# (80, 9)

# %%
df[(df.year==1999) & (df.month=="June")].shape
# Out:
# (236, 9)

# %%
#hour,minute,second ko ek data se nikalna
df["hour"]=df.date_time.dt.hour

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time           date_time  year     month      day  hour
# 0        6/1/1930 22:00 1930-06-01 22:00:00  1930      June   Sunday    22
# ...

# %%
df.hour.value_counts()
# Out:
# 21    2447
# 22    2329
# 20    1829
# 23    1699
# 19    1354
# 0     1207
# 18     975
# 1      818
# 2      688
# 17     607
# 3      515
# 16     412
# 12     394
# 13     377
# 15     372
# 14     355
# 4      327
# 5      317
# 10     256
# 11     227
# 6      210
# 9      188
# 7      186
# 8      152
# Name: hour, dtype: int64

# %%
#correlation
df=pd.read_csv('e:/dataset/analysis/restaurant.csv')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
# C:\Users\pappu kumar\AppData\Local\Temp\ipykernel_472\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
