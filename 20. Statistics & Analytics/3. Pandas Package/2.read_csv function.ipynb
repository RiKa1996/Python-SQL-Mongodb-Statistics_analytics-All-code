# %% [markdown]
# - **2.read_csv function**
#     - csv- **Comma Saprated Values**
#     - it is text file( csv file me sirf text file hi aata hai.)
#     - **csv file ka extension**:-----(**.txt**)-------.txt yhi hum rakhte hai to ok hai.
#     - but hum csv file ka extension **.csv** rakhte hai to , use double click krne per wo file **excel** me open ho jati hai.------ydi humare laptop me ms office ho to.

# %%
import pandas as pd

# %%
df=pd.read_csv("e:/dataset/analysis/empdata_read_csv().txt",names=['empid','empsal','empname'])
df
# Out:
#    empid  empsal empname
# 0    101   50000  rishav
# 1    102   60000   rohit
# 2    103   70000   rehan

# %%
# Ye file comma se saprated hai.
df=pd.read_csv("e:/dataset/analysis/clothes.txt")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   Small     11     monte
# 4  medium     10  cantabil
# 5  Medium     10       cob

# %%
# Ye file colon se saprated hai.
df=pd.read_csv("e:/dataset/analysis/clothes1.txt")
df
# Out:
#      size:price:brand
# 0        small:10:cob
# 1     medium:12:peter
# 2      large:15:monte
# 3      small:11:monte
# 4  medium:10:cantabil
# 5       medium:10:cob

# %% [markdown]
# - **ydi koi file : se,\t se ya is tarah ke symbol se file saprated hai to use** sep=":",sep="\t"

# %%
df=pd.read_csv("e:/dataset/analysis/clothes1.txt",sep=":")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10       cob

# %%
df=pd.read_csv("e:/dataset/analysis/clothes2.txt",sep="\t")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10     monte

# %% [markdown]
# - **agar kisi file me value missing hai to uski jagah pe NaN aa jata hai.** ---NaN
#     - missing values
#         - database---NULL
#         - pandas----NaN

# %%
#file3 -----missing values ke jagah pe NaN values likha aa jata hai.
df=pd.read_csv("e:/dataset/analysis/clothes3.txt")                    # 2	large	15.0	NaN
df
# Out:
#      Size  Price     Brand
# 0   small   10.0       cob
# 1  medium   12.0     peter
# 2   large   15.0       NaN
# 3   small   11.0     monte
# 4  medium   10.0  cantabil
# 5  medium    NaN       cob

# %% [markdown]
# - **clothes3.csv file**

# %%
df=pd.read_csv("e:/dataset/analysis/clothes3.csv")
df
# Out:
#      size  price     brand
# 0   small   10.0       cob
# 1  medium   12.0     peter
# 2   large   15.0     monte
# 3   small   11.0     monte
# 4  medium    NaN  cantabil
# 5  medium   10.0     monte
